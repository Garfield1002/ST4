# %% [markdown]
# # Graphiques de corrélation

# %% [markdown]
# ## Getting the dataset

# %%
## REQUIRED LIBRARIES
# For data wrangling 
import numpy as np
import pandas as pd

# For visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %%
from datetime import datetime
import math

df1 = pd.read_csv(r"data/train.csv").drop(columns=['labels'])
df2 = pd.read_csv(r"data/test.csv")

df1['key'] = 'train'
df2['key'] = 'test'

df = pd.concat([df1,df2],keys=['train','test'])

# %%
## Relations

# %%
# We first review the relation of automatic dishwasher owners with categorical variables
fig, axarr = plt.subplots(22, 1, figsize=(30, 100))
for i, c in enumerate(df.columns):
    if 1 < i < 23: sns.boxplot(x='key', y=c, data = df, ax=axarr[i - 1])

# %%
list(enumerate(df.columns))
# Out:
# [(0, 'userId'),
#  (1, 'age'),
#  (2, 'gender'),
#  (3, 'scentLover'),
#  (4, 'ecoInterest'),
#  (5, 'MrPropre'),
#  (6, 'Antikal'),
#  (7, 'Ariel'),
#  (8, 'Dash'),
#  (9, 'pods'),
#  (10, 'powder'),
#  (11, 'liquid'),
#  (12, 'electricToothbrush'),
#  (13, 'likesPets'),
#  (14, 'hasPet'),
#  (15, 'daysSinceActivity'),
#  (16, 'nbChildren'),
#  (17, 'magasin'),
#  (18, 'moyenneSurface'),
#  (19, 'superMarket'),
#  (20, 'hyperMarket'),
#  (21, 'drive'),
#  (22, 'hardDiscount'),
#  (23, 'key')]
